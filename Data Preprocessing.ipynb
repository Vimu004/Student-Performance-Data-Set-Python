# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Data Exploration

# %%
ds = pd.read_csv(r"C:\Users\user\Downloads\GroupProject 8(DS in python)\Dataset\(New Dataset)student-por.csv")
ds
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
ds.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
ds.describe() #summary statistics
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
ds.info() #basic info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
ds.isnull().sum() #count of null values
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.histplot(data=ds, x='age', bins=20, kde=True, color='blue', alpha=0.7)
plt.title('Distribution of Age')
plt.xlabel('Ages')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # IMPORTANT
# in  Portugal, During the school year, students are evaluated in three periods(G1, G2 ,G3) and the last evaluation (G3) corresponds to the final grade.
#
# There is an important relationship between attributes G2 and G1 and the target attribute G3. This happens because first period grade G1 and second period G2 directly influence the grades for the G3 is the final year grade (given during the third period). Without G2 and G1, predicting G3 is more challenging.

# %%
sns.histplot(data=ds, x='G1', bins=20, kde=True, color='blue', alpha=0.7)
plt.title('Distribution of First Period Grade')
plt.xlabel('First Period Grade')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=ds['G1'])
plt.title('Box Plot of G1'.format('G1'))
plt.xlabel('G1')
plt.show()

# %%
sns.histplot(data=ds, x='G2', bins=20, kde=True, color='blue', alpha=0.7)
plt.title('Distribution of Second Period Grade')
plt.xlabel('Second Period Grade')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=ds['G2'])
plt.title('Box Plot of G2'.format('G2'))
plt.xlabel('G2')
plt.show()

# %%
sns.histplot(data=ds, x='G3', bins=20, kde=True, color='blue', alpha=0.7)
plt.title('Distribution of Third Period Grade/Final Grade')
plt.xlabel('Third Period Grade')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=ds['G3'])
plt.title('Box Plot of G3'.format('G3'))
plt.xlabel('G3')
plt.show()

# %% [markdown]
# # Data Preparation

# %% [markdown]
# #### There's no Null values and Outliers in this dataset

# %% [markdown]
# ### Feature Engineering

# %%
ds['G1 + G2'] = (ds['G1'] + ds['G2']) / 2 #Create a new attribute using G1 and G2
ds.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 G1 + G2
# 0        3     4     1     1       3        4   0  11  11     5.5
# 1        3     3     1     1       3        2   9  11  11    10.0
# 2        3     2     2     3       3        6  12  13  12    12.5
# 3        2     2     1     1       5        0  14  14  14    14.0
# 4        3     2     1     2       5        0  11  13  13    12.0
#
# [5 rows x 34 columns]
