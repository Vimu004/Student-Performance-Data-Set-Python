# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
ds = pd.read_csv(r"C:\Users\user\Downloads\GroupProject 8(DS in python)\Dataset\(New Dataset)student-por.csv")
ds
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
ds['G1 + G2'] = (ds['G1'] + ds['G2']) / 2 #Create a new attribute using G1 and G2
ds.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 G1 + G2
# 0        3     4     1     1       3        4   0  11  11     5.5
# 1        3     3     1     1       3        2   9  11  11    10.0
# 2        3     2     2     3       3        6  12  13  12    12.5
# 3        2     2     1     1       5        0  14  14  14    14.0
# 4        3     2     1     2       5        0  11  13  13    12.0
#
# [5 rows x 34 columns]

# %%
unique_ids = pd.Series(range(1, len(ds) + 1)) #Generate unique IDs for each record
ds['ID'] = unique_ids #Add the unique IDs as a new column to the Dataset
ds.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   goout Dalc  Walc  health  absences  G1  G2  G3 G1 + G2 ID
# 0     4    1     1       3         4   0  11  11     5.5  1
# 1     3    1     1       3         2   9  11  11    10.0  2
# 2     2    2     3       3         6  12  13  12    12.5  3
# 3     2    1     1       5         0  14  14  14    14.0  4
# 4     2    1     2       5         0  11  13  13    12.0  5
#
# [5 rows x 35 columns]

# %%
ds["G3"].hist(bins=20)
plt.title('G3 - Number of students')
# Out:
# Text(0.5, 1.0, 'G3 - Number of students')

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 6))
plt.tight_layout(pad=4)
chosen_columns = ['traveltime','studytime','freetime'] 
axes = axes.flatten()

for i, column in enumerate(chosen_columns):
    axes[i].hist(ds[column], bins=10, color='lightblue', edgecolor='black')
    axes[i].set_xlabel('Time')
    axes[i].set_ylabel('Frequency')
    axes[i].set_title(f'Histogram of {column}')

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 5))
plt.tight_layout(pad=4)
chosen_columns = ['G1','G2','G3'] 
axes = axes.flatten()

for i, column in enumerate(chosen_columns):
    axes[i].hist(ds[column], bins=20, color='lightblue', edgecolor='black')
    axes[i].set_xlabel('Grade')
    axes[i].set_ylabel('Frequency')
    axes[i].set_title(f'Histogram of {column}')

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
plt.tight_layout(pad=4)
chosen_columns = ['Medu','Fedu'] 
axes = axes.flatten()

for i, column in enumerate(chosen_columns):
    axes[i].hist(ds[column], bins=20, color='lightblue', edgecolor='black')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Frequency')
    axes[i].set_title(f'Histogram of {column}')

# %%
chosen_columns = ['studytime','freetime'] 
fig, axes = plt.subplots(1, 2, figsize=(14, 7))
axes = axes.flatten()

for i, column in enumerate(chosen_columns):
    unique_values = ds[column].value_counts().index
    counts = ds[column].value_counts().values
    axes[i].bar(unique_values, counts, color='skyblue', edgecolor='black')
    axes[i].set_xlabel('Values')
    axes[i].set_ylabel('Frequency')
    axes[i].set_title(f'Bar Plot of {column}')
plt.tight_layout()

# %%
chosen_columns = ['Medu','Fedu'] 
fig, axes = plt.subplots(1, 2, figsize=(14, 7))
axes = axes.flatten()

for i, column in enumerate(chosen_columns):
    unique_values = ds[column].value_counts().index
    counts = ds[column].value_counts().values
    axes[i].bar(unique_values, counts, color='skyblue', edgecolor='black')
    axes[i].set_xlabel('Values')
    axes[i].set_ylabel('Frequency')
    axes[i].set_title(f'Bar Plot of {column}')
plt.tight_layout()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=ds['famsize'], data=ds, palette='Set2')
plt.xlabel('Family Size')
plt.ylabel('Student Count')
plt.title('Bar Plot - Family Size')
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=ds['Pstatus'], data=ds, palette='Set2')
plt.xlabel('Parents cohabitation')
plt.ylabel('Student Count')
plt.title('Bar Plot - Parents cohabitation')
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(8, 6))
ds['Mjob'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('Set1'))
plt.title('Pie Chart - Mothers job')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 6))
ds['Fjob'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('Set1'))
plt.title('Pie Chart - Fathers job')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=ds['school'], data=ds, palette='Set1')
plt.xlabel('School(GP - Gabriel Pereira/MS - Mousinho da Silveira)')
plt.ylabel('Count')
plt.title('Count Plot')
plt.show()

# %%
plt.figure(figsize=(8, 6))
ds['reason'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('Set1'))
plt.title('Pie Chart - Reason for choosing the school')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=ds['reason'], data=ds, palette='Set2')
plt.xlabel('Reason For selecting the school')
plt.ylabel('Count')
plt.title('Count Plot')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=ds['higher'], data=ds, palette='Set2')
plt.xlabel('students who Wants to take higher education')
plt.ylabel('Count')
plt.title('Count Plot')
plt.show()
