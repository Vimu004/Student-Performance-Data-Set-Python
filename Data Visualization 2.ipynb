# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
dset = pd.read_csv(r"C:\Users\user\Downloads\GroupProject 8(DS in python)\Dataset\(New Dataset)student-por.csv")
dset
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
dset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
school_counts = dset['school'].value_counts()
plt.figure(figsize=(8, 6))

school_counts.plot(kind='bar', color='skyblue')
plt.title('Student Count in Each School')
plt.xlabel('School')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
school_gp = dset[dset['school'] == 'GP']
school_ms = dset[dset['school'] == 'MS']

# Count number of students in each school based on final grade (G3)
gp_g3_counts = school_gp['G1'].value_counts().sort_index()
ms_g3_counts = school_ms['G2'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(10, 6))

# Plot GP school
plt.bar(gp_g3_counts.index, gp_g3_counts.values, width=0.4, align='center', label='GP', color='skyblue')

# Plot MS school
plt.bar(ms_g3_counts.index + 0.4, ms_g3_counts.values, width=0.4, align='center', label='MS', color='salmon')

plt.title('First Grade(G1) Student Count in Each School')
plt.xlabel('First Grade (G1)')
plt.ylabel('Number of Students')
plt.xticks(range(0, 21))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
school_gp = dset[dset['school'] == 'GP']
school_ms = dset[dset['school'] == 'MS']

# Count number of students in each school based on final grade (G3)
gp_g3_counts = school_gp['G2'].value_counts().sort_index()
ms_g3_counts = school_ms['G2'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(10, 6))

# Plot GP school
plt.bar(gp_g3_counts.index, gp_g3_counts.values, width=0.4, align='center', label='GP', color='skyblue')

# Plot MS school
plt.bar(ms_g3_counts.index + 0.4, ms_g3_counts.values, width=0.4, align='center', label='MS', color='salmon')

plt.title('Second Grade(G2) Student Count in Each School')
plt.xlabel('Second Grade (G2)')
plt.ylabel('Number of Students')
plt.xticks(range(0, 21))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
school_gp = dset[dset['school'] == 'GP']
school_ms = dset[dset['school'] == 'MS']

# Count number of students in each school based on final grade (G3)
gp_g3_counts = school_gp['G3'].value_counts().sort_index()
ms_g3_counts = school_ms['G3'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(10, 6))

# Plot GP school
plt.bar(gp_g3_counts.index, gp_g3_counts.values, width=0.4, align='center', label='GP', color='skyblue')

# Plot MS school
plt.bar(ms_g3_counts.index + 0.4, ms_g3_counts.values, width=0.4, align='center', label='MS', color='salmon')

plt.title('Final Grade(G3) Student Count in Each School')
plt.xlabel('Final Grade (G3)')
plt.ylabel('Number of Students')
plt.xticks(range(0, 21))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
school_freetime_counts = dset.groupby(['school', 'freetime']).size().unstack(fill_value=0)
school_studytime_counts = dset.groupby(['school', 'studytime']).size().unstack(fill_value=0)

# Plotting Free Time and Study Time in Each School
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plot Free Time in Each School
school_freetime_counts.plot(kind='bar', stacked=True, ax=axes[0, 0])
axes[0, 0].set_title('Student Count by Free Time in Each School')
axes[0, 0].set_xlabel('School')
axes[0, 0].set_ylabel('Number of Students')
axes[0, 0].legend(title='Free Time', bbox_to_anchor=(1, 1))
axes[0, 0].grid(axis='y', linestyle='--', alpha=0.7)

# Plot Study Time in Each School
school_studytime_counts.plot(kind='bar', stacked=True, ax=axes[0, 1])
axes[0, 1].set_title('Student Count by Study Time in Each School')
axes[0, 1].set_xlabel('School')
axes[0, 1].set_ylabel('Number of Students')
axes[0, 1].legend(title='Study Time', bbox_to_anchor=(1, 1))
axes[0, 1].grid(axis='y', linestyle='--', alpha=0.7)

# Hide the unused subplot
axes[1, 0].axis('off')
axes[1, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
mother_higher_edu = dset.groupby('Mjob')['higher'].value_counts(normalize=True).unstack()
father_higher_edu = dset.groupby('Fjob')['higher'].value_counts(normalize=True).unstack()

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Mother's job
mother_higher_edu.plot(kind='bar', stacked=True, ax=ax1)
ax1.set_title("Effect of Mother's Job on Higher Education")
ax1.set_xlabel("Mother's Job")
ax1.set_ylabel('Percentage')
ax1.legend(title='Wants to Take Higher Education', bbox_to_anchor=(1, 1))

# Father's job
father_higher_edu.plot(kind='bar', stacked=True, ax=ax2)
ax2.set_title("Effect of Father's Job on Higher Education")
ax2.set_xlabel("Father's Job")
ax2.set_ylabel('Percentage')
ax2.legend(title='Wants to Take Higher Education', bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()

# %%
mother_higher_edu = dset.groupby('Medu')['higher'].value_counts(normalize=True).unstack()
father_higher_edu = dset.groupby('Fedu')['higher'].value_counts(normalize=True).unstack()

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Mother's job
mother_higher_edu.plot(kind='bar', stacked=True, ax=ax1)
ax1.set_title("Effect of Mother's Education level on Higher Education")
ax1.set_xlabel("Mother's Job")
ax1.set_ylabel('Percentage')
ax1.legend(title='Wants to Take Higher Education', bbox_to_anchor=(1, 1))

# Father's job
father_higher_edu.plot(kind='bar', stacked=True, ax=ax2)
ax2.set_title("Effect of Father's Educstion level on Higher Education")
ax2.set_xlabel("Father's Job")
ax2.set_ylabel('Percentage')
ax2.legend(title='Wants to Take Higher Education', bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='romantic', y='G3', data=dset)
plt.title('Relationship between Romantic Relationship and Final Grade (G3)')
plt.xlabel('Romantic Relationship')
plt.ylabel('Final Grade (G3)')
plt.xticks([0, 1], ['No', 'Yes'])  # Label the x-axis ticks
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))

# Plotting students with extra educational support
plt.scatter(dset[dset['schoolsup'] == 'yes']['G3'], dset[dset['schoolsup'] == 'yes'].index,
            color='skyblue', label='With Extra Support')

# Plotting students without extra educational support
plt.scatter(dset[dset['schoolsup'] == 'no']['G3'], dset[dset['schoolsup'] == 'no'].index,
            color='salmon', label='Without Extra Support')

plt.title('Final Grade (G3) vs. Extra Educational Support')
plt.xlabel('Final Grade (G3)')
plt.ylabel('Student Index')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
support_counts = dset.groupby(['G3', 'schoolsup']).size().unstack(fill_value=0)

# Plotting
plt.figure(figsize=(10, 6))
support_counts.plot(kind='bar', stacked=True)
plt.title('Number of Students by Final Grade (G3) and Educational Support from school')
plt.xlabel('Final Grade (G3)')
plt.ylabel('Number of Students')
plt.legend(title='Extra Educational Support', bbox_to_anchor=(1, 1))
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
support_counts = dset.groupby(['G3', 'famsup']).size().unstack(fill_value=0)

# Plotting
plt.figure(figsize=(10, 6))
support_counts.plot(kind='bar', stacked=True)
plt.title('Number of Students by Final Grade (G3) and Educational Support from family')
plt.xlabel('Final Grade (G3)')
plt.ylabel('Number of Students')
plt.legend(title='Extra Educational Support', bbox_to_anchor=(1, 1))
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
labels = ['< 2 hours', '2 to 5 hours', '5 to 10 hours', '> 10 hours']

# Count the number of students in each study time category
study_time_counts = dset['studytime'].value_counts()

# Plotting
fig, ax = plt.subplots(figsize=(8, 6))
pie = ax.pie(study_time_counts, labels=labels, autopct='%1.1f%%', startangle=140)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax.set_title('Distribution of Study Time', y=1.05)  # Move title slightly above the plot
plt.tight_layout()
plt.show()

# %%
labels = ['1', '2', '3', '4','5']

# Count the number of students in each study time category
study_time_counts = dset['freetime'].value_counts()

# Plotting
plt.figure(figsize=(8, 6))
plt.pie(study_time_counts, labels=labels, autopct='%1.1f%%', startangle=140)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax.set_title('Distribution of Study Time', y=1.05)  # Move title slightly above the plot
plt.tight_layout()
plt.show()

# %%
mean_grade_by_studytime = dset.groupby('studytime')['G3'].mean()

# Plotting
plt.figure(figsize=(8, 6))
mean_grade_by_studytime.plot(kind='bar', color='salmon')
plt.title('Average Final Grade (G3) by Study Time')
plt.xlabel('Study Time')
plt.ylabel('Average Final Grade (G3)')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
dset['Dalc_bin'] = pd.cut(dset['Dalc'], bins=5, labels=['Very Low', 'Low', 'Moderate', 'High', 'Very High'])
dset['Walc_bin'] = pd.cut(dset['Walc'], bins=5, labels=['Very Low', 'Low', 'Moderate', 'High', 'Very High'])

# Group data by daily alcohol consumption and calculate average health status
dalc_health = dset.groupby('Dalc_bin')['health'].mean()

# Group data by weekly alcohol consumption and calculate average health status
walc_health = dset.groupby('Walc_bin')['health'].mean()

# Plotting
plt.figure(figsize=(12, 6))

# Bar graph for Daily Alcohol Consumption vs Health
plt.subplot(1, 2, 1)
dalc_health.plot(kind='bar', color='skyblue')
plt.title('Daily Alcohol Consumption vs Health')
plt.xlabel('Daily Alcohol Consumption')
plt.ylabel('Average Health Status')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Bar graph for Weekly Alcohol Consumption vs Health
plt.subplot(1, 2, 2)
walc_health.plot(kind='bar', color='lightgreen')
plt.title('Weekly Alcohol Consumption vs Health')
plt.xlabel('Weekly Alcohol Consumption')
plt.ylabel('Average Health Status')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dset['health'], dset['G3'], alpha=0.5)
plt.title('Final Grade (G3) vs. Health Status')
plt.xlabel('Health Status')
plt.ylabel('Final Grade (G3)')
plt.xticks(range(1, 6), ['Very Bad', 'Bad', 'Normal', 'Good', 'Very Good'])
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
dset['Health_bin'] = pd.cut(dset['health'], bins=5, labels=['Very Bad', 'Bad', 'Normal', 'Good', 'Very Good'])

# Group data by health status and calculate average final grade
health_g3 = dset.groupby('Health_bin')['G3'].mean()

# Plotting
plt.figure(figsize=(8, 6))
health_g3.plot(kind='bar', color='skyblue')
plt.title('Health Status vs Average Final Grade (G3)')
plt.xlabel('Health Status')
plt.ylabel('Average Final Grade (G3)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Dalc', y='absences', data=dset, palette='Set3')
plt.title('Daily Alcohol Consumption vs Absences')
plt.xlabel('Daily Alcohol Consumption')
plt.ylabel('Absences')
plt.xticks(ticks=range(5), labels=['Very Low', 'Low', 'Moderate', 'High', 'Very High'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=dset, x='Medu', hue='Mjob', y='G3', palette='Set1')
plt.title('Final Grade (G3) vs. Mother\'s Education and Job')
plt.xlabel('Mother\'s Education')
plt.ylabel('Average Final Grade (G3)')
plt.tight_layout()
plt.show()

# %%
# Define the order of facets
job_order = ['at_home', 'health', 'other', 'services', 'teacher']
edu_order = [0, 1, 2, 3, 4]

# Create a FacetGrid
g = sns.FacetGrid(dset, row='Medu', col='Mjob', row_order=edu_order, col_order=job_order, height=4, aspect=1)

# Map the histogram distribution of final grade to each facet
g.map(sns.histplot, 'G3', bins=10)

# Set titles and labels
g.set_axis_labels('Final Grade (G3)', 'Frequency')
g.set_titles('Job: {col_name}, Education: {row_name}')
g.set_ylabels('Student count')
g.set_xlabels('Final Grade(G3)')
plt.suptitle('Histogram Distribution of Final Grade Faceted by Mother\'s Job vs. Mother\'s Education', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\AppData\Local\Temp\ipykernel_17668\3839584934.py:17: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# Define the order of facets
job_order = ['at_home', 'health', 'other', 'services', 'teacher']
edu_order = [0, 1, 2, 3, 4]

# Create a FacetGrid
g = sns.FacetGrid(dset, row='Fedu', col='Fjob', row_order=edu_order, col_order=job_order, height=4, aspect=1)

# Map the histogram distribution of final grade to each facet
g.map(sns.histplot, 'G3', bins=10)

# Set titles and labels
g.set_axis_labels('Final Grade (G3)', 'Frequency')
g.set_titles('Job: {col_name}, Education: {row_name}')
g.set_ylabels('Final Grade(G3)')
g.set_xlabels('')
plt.suptitle('Histogram Distribution of Final Grade Faceted by Father\'s Job vs. Father\'s Education', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\AppData\Local\Temp\ipykernel_17668\3428847722.py:17: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
